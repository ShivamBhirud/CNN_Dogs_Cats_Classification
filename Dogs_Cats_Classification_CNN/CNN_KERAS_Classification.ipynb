# %%
# Convolutional Neural Network

# Part 1 - Building the CNN

# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense, Dropout

# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dropout(0.5))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')

classifier.fit_generator(training_set,
#                          steps_per_epoch = 8000,
                         epochs = 25,
                         validation_data = test_set)
#                          validation_steps = 2000
# Out:
# Found 8048 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Epoch 1/25
# 252/252 [==============================] - 51s 201ms/step - loss: 0.6717 - accuracy: 0.5808 - val_loss: 0.7566 - val_accuracy: 0.6635
# Epoch 2/25
# 252/252 [==============================] - 53s 211ms/step - loss: 0.6139 - accuracy: 0.6653 - val_loss: 0.4629 - val_accuracy: 0.7195
# Epoch 3/25
# 252/252 [==============================] - 64s 252ms/step - loss: 0.5584 - accuracy: 0.7158 - val_loss: 0.5143 - val_accuracy: 0.6755
# Epoch 4/25
# 252/252 [==============================] - 50s 199ms/step - loss: 0.5272 - accuracy: 0.7404 - val_loss: 0.5316 - val_accuracy: 0.7605
# Epoch 5/25
# 252/252 [==============================] - 54s 213ms/step - loss: 0.5011 - accuracy: 0.7539 - val_loss: 0.5021 - val_accuracy: 0.7590
# Epoch 6/25
# 252/252 [==============================] - 52s 207ms/step - loss: 0.4883 - accuracy: 0.7617 - val_loss: 0.4484 - val_accuracy: 0.7475
# Epoch 7/25
# 252/252 [==============================] - 70s 278ms/step - loss: 0.4714 - accuracy: 0.7757 - val_loss: 0.3983 - val_accuracy: 0.7685
# Epoch 8/25
# 252/252 [==============================] - 59s 234ms/step - loss: 0.4611 - accuracy: 0.7806 - val_loss: 0.3257 - val_accuracy: 0.7855
# Epoch 9/25
# 252/252 [==============================] - 47s 188ms/step - loss: 0.4603 - accuracy: 0.7831 - val_loss: 0.5105 - val_accuracy: 0.7815
# Epoch 10/25
# 252/252 [==============================] - 75s 297ms/step - loss: 0.4409 - accuracy: 0.7955 - val_loss: 0.5195 - val_accuracy: 0.7885
# Epoch 11/25
# 252/252 [==============================] - 62s 245ms/step - loss: 0.4291 - accuracy: 0.8037 - val_loss: 0.9208 - val_accuracy: 0.7875
# Epoch 12/25
# 252/252 [==============================] - 47s 187ms/step - loss: 0.4278 - accuracy: 0.7997 - val_loss: 0.5013 - val_accuracy: 0.7875
# Epoch 13/25
# 252/252 [==============================] - 47s 187ms/step - loss: 0.4044 - accuracy: 0.8125 - val_loss: 0.3386 - val_accuracy: 0.7935
# Epoch 14/25
# 252/252 [==============================] - 47s 187ms/step - loss: 0.4107 - accuracy: 0.8078 - val_loss: 0.4125 - val_accuracy: 0.7400
# Epoch 15/25
# 252/252 [==============================] - 47s 188ms/step - loss: 0.4096 - accuracy: 0.8159 - val_loss: 0.5108 - val_accuracy: 0.8055
# Epoch 16/25
# 252/252 [==============================] - 47s 187ms/step - loss: 0.3884 - accuracy: 0.8183 - val_loss: 0.4773 - val_accuracy: 0.7870
# Epoch 17/25
# 252/252 [==============================] - 91s 361ms/step - loss: 0.3873 - accuracy: 0.8294 - val_loss: 0.5381 - val_accuracy: 0.8060
# Epoch 18/25
# 252/252 [==============================] - 100s 397ms/step - loss: 0.3791 - accuracy: 0.8287 - val_loss: 0.7639 - val_accuracy: 0.8095
# Epoch 19/25
# 252/252 [==============================] - 94s 373ms/step - loss: 0.3758 - accuracy: 0.8392 - val_loss: 0.2000 - val_accuracy: 0.7995
# Epoch 20/25
# 252/252 [==============================] - 92s 363ms/step - loss: 0.3733 - accuracy: 0.8293 - val_loss: 0.6375 - val_accuracy: 0.8030
# Epoch 21/25
# 252/252 [==============================] - 70s 279ms/step - loss: 0.3610 - accuracy: 0.8402 - val_loss: 0.2232 - val_accuracy: 0.7975
# Epoch 22/25
# 252/252 [==============================] - 79s 312ms/step - loss: 0.3589 - accuracy: 0.8380 - val_loss: 0.5986 - val_accuracy: 0.8115
# Epoch 23/25
# 252/252 [==============================] - 92s 364ms/step - loss: 0.3584 - accuracy: 0.8441 - val_loss: 0.7692 - val_accuracy: 0.7965
# Epoch 24/25
# 252/252 [==============================] - 91s 363ms/step - loss: 0.3511 - accuracy: 0.8470 - val_loss: 0.5108 - val_accuracy: 0.8025
# Epoch 25/25
# 252/252 [==============================] - 92s 366ms/step - loss: 0.3420 - accuracy: 0.8514 - val_loss: 0.2241 - val_accuracy: 0.8120

# %%
# Part 3 - Making new predictions

import numpy as np
from keras.preprocessing import image
from os import listdir
from os.path import isfile, join


predict_dir_path='data/single_prediction/'
onlyfiles = [f for f in listdir(predict_dir_path) if isfile(join(predict_dir_path, f))]


dog_counter = 0 
cat_counter  = 0
for file in onlyfiles:
    img = image.load_img(predict_dir_path+file, target_size=(64, 64))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    classes = classifier.predict(img)
    classes = classes[0][0]
    
    if classes == 0:
        print(file + ": " + 'cat')
        cat_counter += 1
    else:
        print(file + ": " + 'dog')
        dog_counter += 1
print("Total Dogs :",dog_counter)
print("Total Cats :",cat_counter)



# test_image = image.load_img('dataset/single_prediction/cat_or_dog_2.jpg', target_size = (64, 64))
# test_image = image.img_to_array(test_image)
# test_image = np.expand_dims(test_image, axis = 0)
# result = classifier.predict(test_image)
# training_set.class_indices
# if result[0][0] == 1:
#     prediction = 'dog'
# else:
#     prediction = 'cat'
    
# prediction
# Out:
# 22.jpg: dog
# 60.jpg: dog
# 42.jpg: dog
# 59.jpg: dog
# 85.jpg: dog
# 46.jpg: dog
# 87.jpg: dog
# 13.jpg: dog
# 35.jpg: cat
# 38.jpg: cat
# 20.jpg: dog
# 61.jpg: dog
# 21.jpg: dog
# 16.jpg: cat
# 70.jpg: dog
# 68.jpg: cat
# 27.jpg: dog
# 30.jpg: dog
# 32.jpg: cat
# 28.jpg: cat
# 47.jpg: dog
# 5.jpg: dog
# 34.jpg: dog
# 81.jpg: dog
# 76.jpg: dog
# 45.jpg: cat
# 18.jpg: dog
# 62.jpg: dog
# 7.jpg: cat
# 90.jpg: dog
# 75.jpg: dog
# 49.jpg: dog
# 54.jpg: dog
# 11.jpg: cat
# 44.jpg: dog
# 15.jpg: cat
# 6.jpg: dog
# 84.jpg: cat
# 50.jpg: dog
# 8.jpg: dog
# 1.jpg: dog
# 26.jpg: dog
# 33.jpg: dog
# 69.jpg: dog
# 64.jpg: dog
# 58.jpg: dog
# 51.jpg: dog
# 57.jpg: dog
# 19.jpg: dog
# 2.jpg: dog
# 72.jpg: dog
# 63.jpg: dog
# 74.jpg: dog
# 52.jpg: cat
# 67.jpg: dog
# 86.jpg: dog
# 24.jpg: dog
# 65.jpg: dog
# 77.jpg: dog
# 36.jpg: dog
# 10.jpg: cat
# 9.jpg: dog
# 48.jpg: dog
# 23.jpg: dog
# 82.jpg: dog
# 12.jpg: dog
# 43.jpg: dog
# 55.jpg: dog
# 31.jpg: dog
# 80.jpg: cat
# 83.jpg: dog
# 66.jpg: dog
# 4.jpg: dog
# 79.jpg: dog
# 17.jpg: dog
# 39.jpg: dog
# 41.jpg: dog
# 89.jpg: cat
# 14.jpg: dog
# 40.jpg: cat
# 88.jpg: dog
# 53.jpg: dog
# 71.jpg: dog
# 29.jpg: dog
# 56.jpg: dog
# 78.jpg: dog
# 73.jpg: dog
# 37.jpg: cat
# 3.jpg: dog
# 25.jpg: dog
# Total Dogs : 73
# Total Cats : 17
